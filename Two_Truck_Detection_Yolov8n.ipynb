# %%
import zipfile

# Path to your zip file
zip_file_path = 'Data.zip'

# Directory where you want to extract the contents of the zip file
#extract_dir = 'path/to/extract/directory'

# Open and extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall()

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.17 🚀 Python-3.8.10 torch-1.10.0+cu113 CUDA:0 (NVIDIA RTX A5000, 24256MiB)
# Setup complete ✅ (64 CPUs, 62.5 GB RAM, 98.2/227.9 GB disk)

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
results = model.train(data='config.yaml', epochs=50 , batch=8 , save=True, device=1)
ts = model.export(format='torchscript')
# Out:
# Ultralytics YOLOv8.1.17 🚀 Python-3.8.10 torch-1.10.0+cu113 CUDA:1 (NVIDIA RTX A5000, 24256MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
model = YOLO("best.torchscript")
result = model.predict("test.jpg", save = True, conf = 0.25, boxes = True)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# WARNING ⚠️ 'boxes' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_boxes' instead.
# Loading best.torchscript for TorchScript inference...
#
# image 1/1 /LAB/test.jpg: 640x640 1 Tow_Truck, 152.0ms
# Speed: 4.2ms preprocess, 152.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
model = YOLO("best.torchscript")
result = model.predict("test2.jpg", save = True, conf = 0.25, boxes = True)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# WARNING ⚠️ 'boxes' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_boxes' instead.
# Loading best.torchscript for TorchScript inference...
#
# image 1/1 /LAB/test2.jpg: 640x640 2 Tow_Truck_with_vehicles, 162.0ms
# Speed: 4.7ms preprocess, 162.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
model = YOLO("best.torchscript")
result = model.predict("test3.jpg", save = True, conf = 0.25, boxes = True)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# WARNING ⚠️ 'boxes' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_boxes' instead.
# Loading best.torchscript for TorchScript inference...
#
# image 1/1 /LAB/test3.jpg: 640x640 1 Tow_Truck_with_vehicle, 166.5ms
# Speed: 3.9ms preprocess, 166.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
model = YOLO("best.torchscript")
result = model.predict("test.webm", save = True, conf = 0.25, boxes = True)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# WARNING ⚠️ 'boxes' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_boxes' instead.
# Loading best.torchscript for TorchScript inference...
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %%
model = YOLO("best.torchscript")
result = model.predict("test2.mp4", save = True, conf = 0.25, boxes = True)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# WARNING ⚠️ 'boxes' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_boxes' instead.
# Loading best.torchscript for TorchScript inference...
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...
